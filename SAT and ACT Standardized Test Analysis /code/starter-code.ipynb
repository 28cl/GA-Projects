# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# We are consultants hired by the U.S Department of Education, researching on which state(s) to assist in improving participation rates and/or scores for SAT and/or ACT so that resources can be allocated appropriately and effectively.
#
#
# We will investigate the following:
# - Is there any correlation between SAT/ACT participation rates and scores as well as any other external factors?
# - Are there any score or participation rate bias for households with higher or lower median income?
# - Does education spending play a part in higher SAT or ACT scores?

# %% [markdown]
# ### Assumptions:
# - Median family income may not represent the full population as there are also young adults without children taking SAT/ACT.
# - Public Data only reflects spending by the public education system. Data from private school is not included.
# - Education spending is naturally more in states with higher population of students. Hence data for per student was included for a more accurate reflection.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Datasets Used:**
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`median_family_income_2019.csv`](./data/median_family_income_2019.csv): 2019 Median Family Income by State (Families With At Least 1 Child Below 18 Yrs Old)
# * [`Spending_by_state_2019.csv`](./data/Spending_by_state_2019.csv): 2019 Total Education Spending by State
# * [`Spending_by_state_per_student_2019.csv`](./data/Spending_by_state_2019.csv): 2019 Education Spending per student by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# * [Median Family Income by State in 2019](https://datacenter.kidscount.org/data/tables/65-median-family-income-among-households-with-children?loc=1&loct=2#detailed/2/2-53/false/1729/any/365): median_family_income_2019.csv was extracted from the above site
#
#
# * [Data for Expenditure for Public Elementary and Secondary Education by State in 2019](https://nces.ed.gov/programs/digest/d21/tables/dt21_236.25.asp?current=yes): Spending_by_state_2019.csv was extracted from the above site
#
# * [Data for Expenditure for Public Elementary and Secondary Education by State Per Student in 2019](https://nces.ed.gov/programs/digest/d21/tables/dt21_236.70.asp?current=yes): Spending_by_state_per_student_2019.csv was extracted from the above site

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
list1 = [1,2,3,4,5]

# %%
#function to calculate mean 

def cal_average(num):
    sum_num = 0
    for t in num:
        sum_num = sum_num + t           

    avg = sum_num / len(num)
    return avg

# %%
cal_average(list1)
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#function for population standard deviation

def get_std_dev(num):
    var = sum((x - cal_average(num)) ** 2 for x in num) / len(num)
    std_dev = var ** 0.5
    return std_dev

# %%
get_std_dev(list1)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
#removes % sign and convert into decimal approximation

def p2f(percentage):
    return float(percentage.strip('%'))/100

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Library imports:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.stats import pearsonr
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#importing datasets used

sat1 = pd.read_csv('../data/sat_2019.csv')
act1 = pd.read_csv('../data/act_2019.csv')
df = pd.read_csv('../data/median_family_income_2019.csv')
spending = pd.read_csv('../data/Spending_by_state_2019.csv')
spending_per_student = pd.read_csv('../data/Spending_by_state_per_student_2019.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|object|median_family_income_2019|States where ACT and/or SAT Data is Taken|
# |Spending|float|Spending_by_state_2019|2019 Education Spending by State|
# |Family Income|float|median_family_income_2019|2019 Median Family Income by State(Families With At Least 1 Child Below 18 Yrs Old)|
# |SAT Participation Rate|float|sat_2019|SAT Participation Rate in 2019 (converted to decimal approximation)|
# |ACT Participation Rate|float|act_2019|ACT Participation Rate in 2019 (converted to decimal approximation)|
# |SAT Total|float|sat_2019|SAT Total Score in 2019|
# |ACT composite|float|act_2019|Average ACT Score in 2019|

# %%
#checking the headers

sat1.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#checking for datatype and null values

sat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
#checking the headings

df.head()
# Out:
#                   State  Family Income
# 0  District of Columbia         106700
# 1               Alabama          62400
# 2                Alaska          83700
# 3               Arizona          70200
# 4              Arkansas          57300

# %%
#checking for datatype and null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Family Income  52 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 960.0+ bytes

# %%
#merging SAT scores 2019 with main dataframe

df2 = df.merge(sat1, on = "State")
df2.head()
# Out:
#                   State  Family Income Participation Rate  EBRW  Math  Total
# 0  District of Columbia         106700                94%   495   480    975
# 1               Alabama          62400                 7%   583   560   1143
# 2                Alaska          83700                41%   556   541   1097
# 3               Arizona          70200                31%   569   565   1134
# 4              Arkansas          57300                 6%   582   559   1141

# %%
#checking for datatype and null values

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               52 non-null     object
#  1   Family Income       52 non-null     int64
#  2   Participation Rate  52 non-null     object
#  3   EBRW                52 non-null     int64
#  4   Math                52 non-null     int64
#  5   Total               52 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.8+ KB

# %%
#rename columns

df2.rename(columns = {'Participation Rate':'SAT Participation Rate', 'EBRW':'SAT EBRW', 'Math': 'SAT Math', 'Total' : 'SAT Total Score'}, inplace = True)
df2.head()
# Out:
#                   State  Family Income SAT Participation Rate  SAT EBRW  \
# 0  District of Columbia         106700                    94%       495
# 1               Alabama          62400                     7%       583
# 2                Alaska          83700                    41%       556
# 3               Arizona          70200                    31%       569
# 4              Arkansas          57300                     6%       582
#
#    SAT Math  SAT Total Score
# 0       480              975
# 1       560             1143
# 2       541             1097
# 3       565             1134
# 4       559             1141

# %%
#removing unneccessary columns

df2.drop(['SAT EBRW'], axis = 1, inplace = True)
df2.drop(['SAT Math'], axis = 1, inplace = True)
df2.head()
# Out:
#                   State  Family Income SAT Participation Rate  SAT Total Score
# 0  District of Columbia         106700                    94%              975
# 1               Alabama          62400                     7%             1143
# 2                Alaska          83700                    41%             1097
# 3               Arizona          70200                    31%             1134
# 4              Arkansas          57300                     6%             1141

# %%
#merging ACT scores 2019 with main dataframe

df3 = df2.merge(act1, on = "State")
df3.head()
# Out:
#                   State  Family Income SAT Participation Rate  \
# 0  District of Columbia         106700                    94%
# 1               Alabama          62400                     7%
# 2                Alaska          83700                    41%
# 3               Arizona          70200                    31%
# 4              Arkansas          57300                     6%
#
#    SAT Total Score Participation  Composite
# 0              975           32%       23.5
# 1             1143          100%       18.9
# 2             1097           38%       20.1
# 3             1134           73%       19.0
# 4             1141          100%       19.3

# %%
#rename columns

df3.rename(columns = {'Participation':'ACT Participation Rate', 'Composite' : 'ACT Composite'}, inplace = True)
df3.head()
# Out:
#                   State  Family Income SAT Participation Rate  \
# 0  District of Columbia         106700                    94%
# 1               Alabama          62400                     7%
# 2                Alaska          83700                    41%
# 3               Arizona          70200                    31%
# 4              Arkansas          57300                     6%
#
#    SAT Total Score ACT Participation Rate  ACT Composite
# 0              975                    32%           23.5
# 1             1143                   100%           18.9
# 2             1097                    38%           20.1
# 3             1134                    73%           19.0
# 4             1141                   100%           19.3

# %%
#converting participation rate percentages to decimal approximation

df3['SAT Participation Rate'] = df3['SAT Participation Rate'].map(p2f)
df3['ACT Participation Rate'] = df3['ACT Participation Rate'].map(p2f)

# %%
#checking for datatype and null values

df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   Family Income           51 non-null     int64
#  2   SAT Participation Rate  51 non-null     float64
#  3   SAT Total Score         51 non-null     int64
#  4   ACT Participation Rate  51 non-null     float64
#  5   ACT Composite           51 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.8+ KB

# %%
#checking the headings

df3.head()
# Out:
#                   State  Family Income  SAT Participation Rate  \
# 0  District of Columbia         106700                    0.94
# 1               Alabama          62400                    0.07
# 2                Alaska          83700                    0.41
# 3               Arizona          70200                    0.31
# 4              Arkansas          57300                    0.06
#
#    SAT Total Score  ACT Participation Rate  ACT Composite
# 0              975                    0.32           23.5
# 1             1143                    1.00           18.9
# 2             1097                    0.38           20.1
# 3             1134                    0.73           19.0
# 4             1141                    1.00           19.3

# %%
#merging total spending into main dataframe

df4 = df3.merge(spending, on = "State")
df4.head()
# Out:
#                   State  Family Income  SAT Participation Rate  \
# 0  District of Columbia         106700                    0.94
# 1               Alabama          62400                    0.07
# 2                Alaska          83700                    0.41
# 3               Arizona          70200                    0.31
# 4              Arkansas          57300                    0.06
#
#    SAT Total Score  ACT Participation Rate  ACT Composite  Spending
# 0              975                    0.32           23.5   2020361
# 1             1143                    1.00           18.9   7475961
# 2             1097                    0.38           20.1   2408810
# 3             1134                    0.73           19.0   9827893
# 4             1141                    1.00           19.3   5156738

# %%
#renaming the columns

df4.rename(columns = {'SAT Total Score' : 'SAT Total', 'Spending' : 'Spending Total'}, inplace = True)
df4.head()
# Out:
#                   State  Family Income  SAT Participation Rate  SAT Total  \
# 0  District of Columbia         106700                    0.94        975
# 1               Alabama          62400                    0.07       1143
# 2                Alaska          83700                    0.41       1097
# 3               Arizona          70200                    0.31       1134
# 4              Arkansas          57300                    0.06       1141
#
#    ACT Participation Rate  ACT Composite  Spending Total
# 0                    0.32           23.5         2020361
# 1                    1.00           18.9         7475961
# 2                    0.38           20.1         2408810
# 3                    0.73           19.0         9827893
# 4                    1.00           19.3         5156738

# %%
#merging spending per student into main dataframe

df5 = df4.merge(spending_per_student, on = "State")
df5.head()
# Out:
#                   State  Family Income  SAT Participation Rate  SAT Total  \
# 0  District of Columbia         106700                    0.94        975
# 1               Alabama          62400                    0.07       1143
# 2                Alaska          83700                    0.41       1097
# 3               Arizona          70200                    0.31       1134
# 4              Arkansas          57300                    0.06       1141
#
#    ACT Participation Rate  ACT Composite  Spending Total  Spending
# 0                    0.32           23.5         2020361     25502
# 1                    1.00           18.9         7475961     10846
# 2                    0.38           20.1         2408810     20088
# 3                    0.73           19.0         9827893      9650
# 4                    1.00           19.3         5156738     11458

# %%
#renaming the columns

df5.rename(columns = {'Spending' : 'Spending Per Student'}, inplace = True)
df5.head()
# Out:
#                   State  Family Income  SAT Participation Rate  SAT Total  \
# 0  District of Columbia         106700                    0.94        975
# 1               Alabama          62400                    0.07       1143
# 2                Alaska          83700                    0.41       1097
# 3               Arizona          70200                    0.31       1134
# 4              Arkansas          57300                    0.06       1141
#
#    ACT Participation Rate  ACT Composite  Spending Total  Spending Per Student
# 0                    0.32           23.5         2020361                 25502
# 1                    1.00           18.9         7475961                 10846
# 2                    0.38           20.1         2408810                 20088
# 3                    0.73           19.0         9827893                  9650
# 4                    1.00           19.3         5156738                 11458

# %%
#re-ordering columns

df5 = df5[['State', 'Spending Total', 'Spending Per Student', 'Family Income', 'SAT Participation Rate', 'ACT Participation Rate', 'SAT Total', 'ACT Composite']]

# %%
#checking the headings

df5.head()
# Out:
#                   State  Spending Total  Spending Per Student  Family Income  \
# 0  District of Columbia         2020361                 25502         106700
# 1               Alabama         7475961                 10846          62400
# 2                Alaska         2408810                 20088          83700
# 3               Arizona         9827893                  9650          70200
# 4              Arkansas         5156738                 11458          57300
#
#    SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 0                    0.94                    0.32        975           23.5
# 1                    0.07                    1.00       1143           18.9
# 2                    0.41                    0.38       1097           20.1
# 3                    0.31                    0.73       1134           19.0
# 4                    0.06                    1.00       1141           19.3

# %%
#checking for datatype and null values

df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   Spending Total          51 non-null     int64
#  2   Spending Per Student    51 non-null     int64
#  3   Family Income           51 non-null     int64
#  4   SAT Participation Rate  51 non-null     float64
#  5   ACT Participation Rate  51 non-null     float64
#  6   SAT Total               51 non-null     int64
#  7   ACT Composite           51 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 3.6+ KB

# %%
#converting datatypes to float

df5['Spending Total'] = df5['Spending Total'].astype(float)
df5['Spending Per Student'] = df5['Spending Per Student'].astype(float)
df5['Family Income'] = df5['Family Income'].astype(float)
df5['SAT Total'] = df5['SAT Total'].astype(float)

# %%
#checking for datatype and null values

df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   Spending Total          51 non-null     float64
#  2   Spending Per Student    51 non-null     float64
#  3   Family Income           51 non-null     float64
#  4   SAT Participation Rate  51 non-null     float64
#  5   ACT Participation Rate  51 non-null     float64
#  6   SAT Total               51 non-null     float64
#  7   ACT Composite           51 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 3.6+ KB

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Step 1:
# Summary Statistics

# %%
#Summary statistics
df5.describe().T
# Out:
#                         count          mean           std         min  \
# Spending Total           51.0  1.307579e+07  1.638873e+07  1434930.00
# Spending Per Student     51.0  1.451496e+04  4.348049e+03     8726.00
# Family Income            51.0  7.884510e+04  1.424724e+04    53100.00
# SAT Participation Rate   51.0  4.905882e-01  3.874760e-01        0.02
# ACT Participation Rate   51.0  5.866667e-01  3.451589e-01        0.06
# SAT Total                51.0  1.113078e+03  9.719791e+01      943.00
# ACT Composite            51.0  2.146471e+01  2.194523e+00       17.90
#
#                                 25%         50%          75%         max
# Spending Total          3167756.500  7646150.00  15664846.50  85566797.0
# Spending Per Student      11240.500    13315.00     17344.00     26727.0
# Family Income             69750.000    77200.00     86950.00    111800.0
# SAT Participation Rate        0.055        0.54         0.82         1.0
# ...

# %% [markdown]
# ### Step 2:
# Dictionary Comprehension

# %%
#dictionary comprehension

sd = {'Spending Total' : get_std_dev(df5['Spending Total']), 'Spending Per Student' : get_std_dev(df5['Spending Per Student']), 'Family Income' : get_std_dev(df5['Family Income']), 'SAT Participation Rate' : get_std_dev(df5['SAT Participation Rate']), 'SAT Total' : get_std_dev(df5['SAT Total']), 'ACT Participation Rate' : get_std_dev(df5['ACT Participation Rate']), 'ACT Composite' : get_std_dev(df5['ACT Composite'])}
sd
# Out:
# {'Spending Total': 16227263.883061012,
#  'Spending Per Student': 4305.210363382019,
#  'Family Income': 14106.865436423808,
#  'SAT Participation Rate': 0.3836584048685726,
#  'SAT Total': 96.24027185617864,
#  'ACT Participation Rate': 0.3417582373703047,
#  'ACT Composite': 2.172901153595978}

# %% [markdown]
# **Interpretation:** Standard Deviation is different as .describe() is using Sample Standard Deviation whereas get_std_dev is using Population Standard Deviation.

# %% [markdown]
# ### Step 3:
# Investigate trends in the data

# %%
#states with the highest participation rates for SAT in 2019

df_sat_part = df5.sort_values('SAT Participation Rate', ascending = False)
df_sat_part.head(9)
# Out:
#            State  Spending Total  Spending Per Student  Family Income  \
# 39  Rhode Island       2515700.0               18981.0        82300.0
# 12         Idaho       2497424.0                8726.0        72500.0
# 22      Michigan      18128540.0               13315.0        73700.0
# 6       Colorado      10092540.0               12465.0        92500.0
# 7    Connecticut      11133063.0               21964.0        98300.0
# 8       Delaware       2204611.0               16595.0        77200.0
# 9        Florida      28425418.0               10184.0        65800.0
# 13      Illinois      32207915.0               18208.0        86600.0
# 19         Maine       2830663.0               17419.0        75600.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 39                    1.00                    0.12      995.0           24.7
# 12                    1.00                    0.31      993.0           22.5
# ...

# %%
#states with the highest participation rates for ACT in 2019

df_act_part = df5.sort_values('ACT Participation Rate', ascending = False)
df_act_part.head(16)
# Out:
#              State  Spending Total  Spending Per Student  Family Income  \
# 50         Wyoming       1530465.0               17919.0        80000.0
# 17        Kentucky       7646150.0               12784.0        65100.0
# 24     Mississippi       4361150.0               10071.0        53100.0
# 1          Alabama       7475961.0               10846.0        62400.0
# 26         Montana       1783700.0               13068.0        71600.0
# 27        Nebraska       4160210.0               14246.0        80300.0
# 28          Nevada       4495961.0                9613.0        69300.0
# 33  North Carolina      15213245.0               10589.0        68900.0
# 18       Louisiana       8484794.0               12512.0        61300.0
# 35            Ohio      22778613.0               14021.0        72100.0
# 36        Oklahoma       6432157.0                9828.0        62200.0
# 42       Tennessee      10017249.0               10885.0        66400.0
# ...

# %%
#states with the lowest participation rates for SAT in 2019

df_sat_part = df5.sort_values('SAT Participation Rate', ascending = False)
df_sat_part.tail(8)
# Out:
#            State  Spending Total  Spending Per Student  Family Income  \
# 16        Kansas       5638278.0               12295.0        75700.0
# 41  South Dakota       1434930.0               11453.0        75100.0
# 27      Nebraska       4160210.0               14246.0        80300.0
# 24   Mississippi       4361150.0               10071.0        53100.0
# 15          Iowa       6143589.0               12907.0        77900.0
# 49     Wisconsin      10904913.0               13527.0        82000.0
# 50       Wyoming       1530465.0               17919.0        80000.0
# 34  North Dakota       1597597.0               14792.0        87600.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 16                    0.04                    0.72     1241.0           21.2
# 41                    0.03                    0.75     1268.0           21.6
# 27                    0.03                    1.00     1260.0           20.0
# ...

# %%
#states with the lowest participation rates for ACT in 2019

df_act_part = df5.sort_values('ACT Participation Rate', ascending = False)
df_act_part.tail(5)
# Out:
#             State  Spending Total  Spending Per Student  Family Income  \
# 38   Pennsylvania      29235226.0               18076.0        80700.0
# 29  New Hampshire       3047648.0               17491.0       102400.0
# 8        Delaware       2204611.0               16595.0        77200.0
# 39   Rhode Island       2515700.0               18981.0        82300.0
# 19          Maine       2830663.0               17419.0        75600.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 38                    0.70                    0.17     1082.0           23.6
# 29                    0.95                    0.14     1059.0           25.0
# 8                     1.00                    0.13      985.0           24.1
# 39                    1.00                    0.12      995.0           24.7
# 19                    0.99                    0.06     1013.0           24.3

# %%
#states with the highest average/composite scores for SAT in 2019

df_sat_score = df5.sort_values('SAT Total', ascending = False)
df_sat_score.head()
# Out:
#            State  Spending Total  Spending Per Student  Family Income  \
# 23     Minnesota      11824723.0               14250.0        97200.0
# 49     Wisconsin      10904913.0               13527.0        82000.0
# 41  South Dakota       1434930.0               11453.0        75100.0
# 34  North Dakota       1597597.0               14792.0        87600.0
# 27      Nebraska       4160210.0               14246.0        80300.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 23                    0.04                    0.95     1284.0           21.4
# 49                    0.03                    1.00     1283.0           20.3
# 41                    0.03                    0.75     1268.0           21.6
# 34                    0.02                    0.96     1263.0           19.9
# 27                    0.03                    1.00     1260.0           20.0

# %%
#states with the highest average/composite scores for ACT in 2019

df_act_score = df5.sort_values('ACT Composite', ascending = False)
df_act_score.head()
# Out:
#             State  Spending Total  Spending Per Student  Family Income  \
# 21  Massachusetts      18471917.0               20299.0       111800.0
# 7     Connecticut      11133063.0               21964.0        98300.0
# 29  New Hampshire       3047648.0               17491.0       102400.0
# 39   Rhode Island       2515700.0               18981.0        82300.0
# 32       New York      65549087.0               26727.0        83600.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 21                    0.81                    0.21     1120.0           25.5
# 7                     1.00                    0.22     1046.0           25.5
# 29                    0.95                    0.14     1059.0           25.0
# 39                    1.00                    0.12      995.0           24.7
# 32                    0.79                    0.22     1064.0           24.5

# %%
#states with the lowest average/composite scores for SAT in 2019

df_sat_score = df5.sort_values('SAT Total', ascending = False)
df_sat_score.tail()
# Out:
#                    State  Spending Total  Spending Per Student  Family Income  \
# 12                 Idaho       2497424.0                8726.0        72500.0
# 8               Delaware       2204611.0               16595.0        77200.0
# 0   District of Columbia       2020361.0               25502.0       106700.0
# 36              Oklahoma       6432157.0                9828.0        62200.0
# 48         West Virginia       3287865.0               13324.0        58500.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 12                    1.00                    0.31      993.0           22.5
# 8                     1.00                    0.13      985.0           24.1
# 0                     0.94                    0.32      975.0           23.5
# 36                    0.22                    1.00      963.0           18.9
# 48                    0.99                    0.49      943.0           20.8

# %%
#states with the lowest average/composite scores for ACT in 2019

df_act_score = df5.sort_values('ACT Composite', ascending = False)
df_act_score.tail(7)
# Out:
#              State  Spending Total  Spending Per Student  Family Income  \
# 3          Arizona       9827893.0                9650.0        70200.0
# 36        Oklahoma       6432157.0                9828.0        62200.0
# 1          Alabama       7475961.0               10846.0        62400.0
# 18       Louisiana       8484794.0               12512.0        61300.0
# 40  South Carolina       8585210.0               12197.0        66700.0
# 24     Mississippi       4361150.0               10071.0        53100.0
# 28          Nevada       4495961.0                9613.0        69300.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 3                     0.31                    0.73     1134.0           19.0
# 36                    0.22                    1.00      963.0           18.9
# 1                     0.07                    1.00     1143.0           18.9
# 18                    0.05                    1.00     1200.0           18.8
# ...

# %%
#states with highest median family income

df_income = df5.sort_values('Family Income', ascending = False)
df_income.head(5)
# Out:
#                    State  Spending Total  Spending Per Student  Family Income  \
# 21         Massachusetts      18471917.0               20299.0       111800.0
# 30            New Jersey      29864232.0               22507.0       108400.0
# 0   District of Columbia       2020361.0               25502.0       106700.0
# 20              Maryland      13968752.0               16932.0       103600.0
# 29         New Hampshire       3047648.0               17491.0       102400.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 21                    0.81                    0.21     1120.0           25.5
# 30                    0.82                    0.25     1090.0           24.2
# 0                     0.94                    0.32      975.0           23.5
# 20                    0.82                    0.28     1058.0           22.3
# 29                    0.95                    0.14     1059.0           25.0

# %%
#states with lowest median family income

df_income = df5.sort_values('Family Income', ascending = False)
df_income.tail(5)
# Out:
#             State  Spending Total  Spending Per Student  Family Income  \
# 18      Louisiana       8484794.0               12512.0        61300.0
# 48  West Virginia       3287865.0               13324.0        58500.0
# 4        Arkansas       5156738.0               11458.0        57300.0
# 31     New Mexico       3490740.0               10543.0        53400.0
# 24    Mississippi       4361150.0               10071.0        53100.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 18                    0.05                    1.00     1200.0           18.8
# 48                    0.99                    0.49      943.0           20.8
# 4                     0.06                    1.00     1141.0           19.3
# 31                    0.18                    0.63     1073.0           19.3
# 24                    0.03                    1.00     1237.0           18.4

# %%
#states with highest education spending

df_spending = df5.sort_values('Spending Total', ascending = False)
df_spending.head(5)
# Out:
#          State  Spending Total  Spending Per Student  Family Income  \
# 5   California      85566797.0               14588.0        85300.0
# 32    New York      65549087.0               26727.0        83600.0
# 43       Texas      53618624.0               10680.0        72100.0
# 13    Illinois      32207915.0               18208.0        86600.0
# 30  New Jersey      29864232.0               22507.0       108400.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 5                     0.63                    0.23     1065.0           22.6
# 32                    0.79                    0.22     1064.0           24.5
# 43                    0.68                    0.39     1022.0           20.5
# 13                    1.00                    0.35     1013.0           24.3
# 30                    0.82                    0.25     1090.0           24.2

# %%
#states with lowest education spending

df_spending = df5.sort_values('Spending Total', ascending = False)
df_spending.tail(5)
# Out:
#            State  Spending Total  Spending Per Student  Family Income  \
# 45       Vermont       1847486.0               23031.0        82200.0
# 26       Montana       1783700.0               13068.0        71600.0
# 34  North Dakota       1597597.0               14792.0        87600.0
# 50       Wyoming       1530465.0               17919.0        80000.0
# 41  South Dakota       1434930.0               11453.0        75100.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 45                    0.66                    0.20     1106.0           24.1
# 26                    0.09                    1.00     1199.0           19.8
# 34                    0.02                    0.96     1263.0           19.9
# 50                    0.03                    1.00     1238.0           19.8
# 41                    0.03                    0.75     1268.0           21.6

# %%
#states with highest education spending per student

df_spending_student = df5.sort_values('Spending Per Student', ascending = False)
df_spending_student.head(5)
# Out:
#                    State  Spending Total  Spending Per Student  Family Income  \
# 32              New York      65549087.0               26727.0        83600.0
# 0   District of Columbia       2020361.0               25502.0       106700.0
# 45               Vermont       1847486.0               23031.0        82200.0
# 30            New Jersey      29864232.0               22507.0       108400.0
# 7            Connecticut      11133063.0               21964.0        98300.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 32                    0.79                    0.22     1064.0           24.5
# 0                     0.94                    0.32      975.0           23.5
# 45                    0.66                    0.20     1106.0           24.1
# 30                    0.82                    0.25     1090.0           24.2
# 7                     1.00                    0.22     1046.0           25.5

# %%
#states with lowest education spending per student

df_spending_student = df5.sort_values('Spending Per Student', ascending = False)
df_spending_student.tail(6)
# Out:
#           State  Spending Total  Spending Per Student  Family Income  \
# 24  Mississippi       4361150.0               10071.0        53100.0
# 36     Oklahoma       6432157.0                9828.0        62200.0
# 3       Arizona       9827893.0                9650.0        70200.0
# 28       Nevada       4495961.0                9613.0        69300.0
# 44         Utah       5382401.0                8751.0        87300.0
# 12        Idaho       2497424.0                8726.0        72500.0
#
#     SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 24                    0.03                    1.00     1237.0           18.4
# 36                    0.22                    1.00      963.0           18.9
# 3                     0.31                    0.73     1134.0           19.0
# 28                    0.20                    1.00     1156.0           17.9
# 44                    0.04                    1.00     1230.0           20.3
# ...

# %%
#filter states with spending per student lower than the national average per student spending
#sorting them by their ascending ACT Composite Scores

df_lower_ACT = df5[(df5['Spending Per Student']) < (df5['Spending Per Student'].mean())].sort_values('ACT Composite', ascending = True).reset_index(drop = True)
df_lower_ACT.head()
# Out:
#             State  Spending Total  Spending Per Student  Family Income  \
# 0          Nevada       4495961.0                9613.0        69300.0
# 1     Mississippi       4361150.0               10071.0        53100.0
# 2  South Carolina       8585210.0               12197.0        66700.0
# 3       Louisiana       8484794.0               12512.0        61300.0
# 4         Alabama       7475961.0               10846.0        62400.0
#
#    SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 0                    0.20                    1.00     1156.0           17.9
# 1                    0.03                    1.00     1237.0           18.4
# 2                    0.68                    0.78     1030.0           18.8
# 3                    0.05                    1.00     1200.0           18.8
# 4                    0.07                    1.00     1143.0           18.9

# %%
#filter states with spending per student lower than the national average per student spending
#sorting them by their ascending SAT Total Scores

df_lower_SAT = df5[(df5['Spending Per Student']) < (df5['Spending Per Student'].mean())].sort_values('SAT Total', ascending = True).reset_index(drop = True)
df_lower_SAT.head()
# Out:
#            State  Spending Total  Spending Per Student  Family Income  \
# 0  West Virginia       3287865.0               13324.0        58500.0
# 1       Oklahoma       6432157.0                9828.0        62200.0
# 2          Idaho       2497424.0                8726.0        72500.0
# 3        Florida      28425418.0               10184.0        65800.0
# 4       Michigan      18128540.0               13315.0        73700.0
#
#    SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 0                    0.99                    0.49      943.0           20.8
# 1                    0.22                    1.00      963.0           18.9
# 2                    1.00                    0.31      993.0           22.5
# 3                    1.00                    0.54      999.0           20.1
# 4                    1.00                    0.19     1003.0           24.4

# %%
#filter states with spending per student higher than the national average per student spending
#sorting them by their ACT Composite Scores
df_higher_ACT = df5[(df5['Spending Per Student']) > (df5['Spending Per Student'].mean())].sort_values('ACT Composite', ascending = False).reset_index(drop = True)
df_higher_ACT.head()
# Out:
#            State  Spending Total  Spending Per Student  Family Income  \
# 0  Massachusetts      18471917.0               20299.0       111800.0
# 1    Connecticut      11133063.0               21964.0        98300.0
# 2  New Hampshire       3047648.0               17491.0       102400.0
# 3   Rhode Island       2515700.0               18981.0        82300.0
# 4       New York      65549087.0               26727.0        83600.0
#
#    SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 0                    0.81                    0.21     1120.0           25.5
# 1                    1.00                    0.22     1046.0           25.5
# 2                    0.95                    0.14     1059.0           25.0
# 3                    1.00                    0.12      995.0           24.7
# 4                    0.79                    0.22     1064.0           24.5

# %%
#filter states with spending per student higher than the national average per student spending
#sorting them by their SAT Total Scores
df_higher_SAT = df5[(df5['Spending Per Student']) > (df5['Spending Per Student'].mean())].sort_values('SAT Total', ascending = False).reset_index(drop = True)
df_higher_SAT.head()
# Out:
#            State  Spending Total  Spending Per Student  Family Income  \
# 0   North Dakota       1597597.0               14792.0        87600.0
# 1        Wyoming       1530465.0               17919.0        80000.0
# 2  Massachusetts      18471917.0               20299.0       111800.0
# 3        Vermont       1847486.0               23031.0        82200.0
# 4         Hawaii       2924320.0               17269.0        93300.0
#
#    SAT Participation Rate  ACT Participation Rate  SAT Total  ACT Composite
# 0                    0.02                    0.96     1263.0           19.9
# 1                    0.03                    1.00     1238.0           19.8
# 2                    0.81                    0.21     1120.0           25.5
# 3                    0.66                    0.20     1106.0           24.1
# 4                    0.54                    0.80     1100.0           19.0

# %% [markdown]
# ### Results from Step 3:
#
# **[Highest Participation Rate]**
#
# - 2019 SAT: Rhode Island, Idaho, Michigan, Colorado, Connecticut, Delaware, Florida, Illinois
# - 2019 ACT: Kentucky, Mississippi, Alabama, Montana, Nebraska, Nevada, North Carolina, Louisiana, Ohio, Oklahoma, Tennessee, Arkansas, Utah, Wisconsin, North Dakota
#
# **[Lowest Participation Rate]**
#
# - 2019 SAT: North Dakota, Wyoming, Wisconsin, Iowa, Mississippi, Nebraska, South Dakota
# - 2019 ACT: Maine, Rhode Island, Delaware, New Hampshire, Pennsylvania
#
# **[Highest Total/Composite Scores]**
#
# - 2019 SAT: Minnesota, Wisconsin, South Dakota, North Dakota, Nebraska
# - 2019 ACT: Massachusetts, Connecticut, New Hampshire, Rhode Island, New York
#
# **[Lowest Total/Composite Scores]**
#
# - 2019 SAT: West Virginia, Oklahoma, District of Columbia, Delaware, Idaho
# - 2019 ACT: Nevada, Mississippi, South Carolina, Louisiana, Alabama, Oklahoma, Arizona
#
# **[Median Family Income]**
#
# - Highest States: Massachusetts, New Jersey, District of Columbia, Maryland, New Hampshire
# - Lowest States: Mississippi, New Mexico, Arkansas, West Virginia, Louisiana
#
# **[Total Education Spending]**
#
# - Higest States: California, New York, Texas, Illinois, New Jersey
# - Lowest States: South Dakota, Wyoming, North Dakota, Montana, Vermont
#
# **[Education Spending Per Student]**
#
# - Higest States: New York, District of Columbia, Vermont, New Jersey, Connecticut
# - Lowest States: Idaho, Utah, Nevada, Arizona, Oklahoma
#
# **[States with lower than average Per Student Education Spending sorted by lowest Total/Composite Scores]**
# - 2019 ACT: Nevada, Mississippi, South Carolina, Louisiana, Alabama, Oklahoma
# - 2019 SAT: West Virginia, Oklahoma, Idaho, Florida, Michigan
#
# **[States with higher than average Per Student Education Spending sorted by highest Total/Composite Scores]**
# - 2019 ACT: Massachusetts, Connecticut, New Hampshire, Rhode Island, New York
# - 2019 SAT: North Dakota, Wyoming, Massachusetts, Vermont, Hawaii

# %% [markdown]
# **Interpretation:**
# - None of the states with the highest total education spending resulted in highest total/composite scores
# - None of the states with the lowest total education spending resulted in lowest total/composite scores
# - None of the states with the highest education spending per student resulted in highest total/composite scores
# - Neveda, Oklahoma, Idaho, Arizona spent the least per student and they also produced lowest ACT/SAT total/composite scores
# - Massachusetts Median Family income is one of the highest, and they scored one the highest for 2019 ACT
# - District of Columbia Median Family Income is one of the highest, and they scored one the lowest for 2019 SAT
# - None of the states with the lowest Median Family Income have the highest total/composite scores
# - Mississippi, West Virginia, Louisiana has one of the lowest Median Family Income and they also produced lowest total/composite scores
# - Delaware has one of the highest participation rate for 2019 SAT and they scored one the lowest for 2019 SAT
# - Nevada, Mississippi, Alabama, Lousiana and Oklahoma has one of the highest participation rate for 2019 ACT and they scored one the lowest for 2019 ACT
# - Nevada, Mississippi, Alabama, Lousiana and Oklahoma not only have one of the highest participation rate for 2019 ACT and they scored one the lowest for 2019 ACT, they also have lower than National Average Per Student Spending
# - New York, North Dakota, Rhode Island, Massachusetts, Connecticut, New Hampshire were states with the highest ACT/SAT scores and their Per Student Education Spending was above the National Average Per Student Spending

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Prepare Data
plt.rcParams["figure.figsize"] = (10, 12)
classification = df5['State']
df4ACT = df5['ACT Participation Rate'] * -1

#Chart
bar_plot = sns.barplot(x = df4ACT, y = 'State', order = classification, data = df5, lw=0, color = "green")
bar_plot = sns.barplot(x = 'SAT Participation Rate', y = 'State', order = classification, data = df5, lw=0, color = "blue")
plt.title("ACT vs SAT Participation Rate", fontsize = 18)
plt.xlabel("ACT / SAT Participation Rate (decimal approximation)")
plt.show()

# %% [markdown]
# **Interpretation:**
# This shows the participation rate of ACT vs SAT.
# Some states have students taking both ACT and SAT. This can be seen in states that have 100% participation rate for either ACT or SAT but still show participation in the other.
# This could be due to a variety of factors:
# - ACT/SAT tests are mandatory
# - ACT/SAT tests are free
# - Student did not do well for one and decided to take the other
# - Student had a change of mind in the school they want to attend and taking the other test is said to be more advantageous

# %%
#pairplot

sns.pairplot(df5);

# %%
#correlation heatmap

plt.figure(figsize = (18,10))
sns.heatmap(df5.corr(), annot = True);
plt.title("Correlation for all data", fontsize = 18);

# %% [markdown]
# **Interpretation:**
# - Total Spending on Elementary/Secondary schools does not have a correlation with the participation rate/score for both SAT and ACT
# - Total Spending on Elementary/Secondary schools does not have a correlation with the Median Family Income
# - Spending Per Student has somewhat a positive correlation with Median Family Income
# - Spending Per Student has somewhat a positive correlation with ACT Composite Score
# - Spending Per Student has somewhat a negative correlation with ACT Participation Rate
# - Median Family Income has a positive correlation with ACT Composite Score
# - SAT Composite Score and SAT Participation Rate are negatively correlated
# - ACT Composite Score and ACT Participation Rate are negatively correlated

# %%
#correlation heatmap

corr = df5[['SAT Participation Rate', 'SAT Total']].corr()

plt.figure(figsize = (5,5))
hm_sat = sns.heatmap(corr, annot = True)
hm_sat.set(title = 'Correlation between SAT Total Score and SAT Participation Rate')
plt.yticks(rotation=0);

# %%
#correlation heatmap

corr1 = df5[['ACT Participation Rate', 'ACT Composite']].corr()

plt.figure(figsize = (5,5))
hm_sat1 = sns.heatmap(corr1, annot = True)
hm_sat1.set(title = 'Correlation between ACT Composite Scores and ACT Participation Rate')
plt.yticks(rotation=0);

# %%
#finding the correlation and p value between the score and participation rate for SAT and ACT

corr2, p_value1 = pearsonr(df5['SAT Participation Rate'], df5['SAT Total'])
corr3, p_value2 = pearsonr(df5['ACT Participation Rate'], df5['ACT Composite'])

print(f'The correlation between participation rate and SAT Total Score is {corr2}, and the p value is {p_value1}')
print(f'The correlation between participation rate and ACT Composite Score is {corr3}, and the p value is {p_value2}')
# Out:
# The correlation between participation rate and SAT Total Score is -0.8617856279968542, and the p value is 4.711438943124115e-16
# The correlation between participation rate and ACT Composite Score is -0.8668191877685288, and the p value is 2.017197654188118e-16

# %%
#correlation heatmap

corr4 = df5[['Family Income', 'ACT Composite', 'SAT Total']].corr()

plt.figure(figsize = (8,5))
hm_sat = sns.heatmap(corr4, annot = True)
hm_sat.set(title = 'Correlation between Family Income, ACT composite score and SAT Total Score');
plt.yticks(rotation=0);

# %%
#finding the correlation and p value between family income and SAT/ACT Total/Composite scores

corr5, p_value3 = pearsonr(df5['Family Income'], df5['SAT Total'])
corr6, p_value4 = pearsonr(df5['Family Income'], df5['ACT Composite'])

print(f'The correlation between Family Income and SAT Total score is {corr5}, and the p value is {p_value3}')
print(f'The correlation between Family Income and ACT Composite Score is {corr6}, and the p value is {p_value4}')
# Out:
# The correlation between Family Income and SAT Total score is -0.06699126584998383, and the p value is 0.6404439271652925
# The correlation between Family Income and ACT Composite Score is 0.6521621363720425, and the p value is 2.1649117698217518e-07

# %%
#correlation heatmap

corr7 = df5[['Spending Total', 'Spending Per Student', 'Family Income']].corr()

plt.figure(figsize = (8,5))
hm_sat = sns.heatmap(corr7, annot = True)
hm_sat.set(title = 'Correlation between Total Spending, Spending Per Student and Family Income');
plt.yticks(rotation=0);

# %%
#finding the correlation and p value between family income and spending by state and by per student

corr8, p_value5 = pearsonr(df5['Family Income'], df5['Spending Total'])
corr9, p_value6 = pearsonr(df5['Family Income'], df5['Spending Per Student'])

print(f'The correlation between Family Income and Total Spending for Education is {corr8}, and the p value is {p_value5}')
print(f'The correlation between Family Income and Spending Per Student is {corr9}, and the p value is {p_value6}')
# Out:
# The correlation between Family Income and Total Spending for Education is 0.13853487708863318, and the p value is 0.33229809277549294
# The correlation between Family Income and Spending Per Student is 0.6596371218220087, and the p value is 1.4053237709736058e-07

# %%
#linear regression model fit for participation rates vs scores

fig, ax = plt.subplots(2, figsize=(10, 10))

sns.regplot(ax = ax[0],x = df5['SAT Participation Rate'], y = df5['SAT Total'])
ax[0].set_xlabel("SAT Participation Rate")
ax[0].set_ylabel("SAT Total")
ax[0].set_title('SAT Participation Rate vs SAT Total Score')

sns.regplot(ax = ax[1],x = df5['ACT Participation Rate'], y = df5['ACT Composite'])
ax[1].set_xlabel("ACT Participation Rate")
ax[1].set_ylabel("ACT Composite")
ax[1].set_title('ACT Participation Rate vs ACT Composite')

fig.tight_layout()
plt.show();

# %% [markdown]
# **Interpretation:**
# The trend for both ACT and SAT is the same with regard to Participation Rate vs Total/Composite Scores. Both ACT and SAT scores seem to decrease as the participation rate increases; negatively correlated.

# %%
#linear regression model fit for family income vs participation rates and scores

fig, ax = plt.subplots(nrows = 4, figsize=(10, 20), sharex = True)

sns.regplot(ax = ax[0], x = df5['Family Income'], y = df5['ACT Composite'])
ax[0].set_xlabel("Family Income")
ax[0].set_ylabel("ACT Composite")
ax[0].set_title('Family Income vs ACT Composite Score')

sns.regplot(ax = ax[1], x = df5['Family Income'], y = df5['SAT Total'])
ax[1].set_xlabel("Family Income")
ax[1].set_ylabel("SAT Total")
ax[1].set_title('Family Income vs SAT Total Score')

sns.regplot(ax = ax[2], x = df5['Family Income'], y = df5['ACT Participation Rate'])
ax[2].set_xlabel("Family Income")
ax[2].set_ylabel("ACT Participation Rate")
ax[2].set_title('Family Income vs ACT Participation Rate')

sns.regplot(ax = ax[3], x = df5['Family Income'], y = df5['SAT Participation Rate'])
ax[3].set_xlabel("Family Income")
ax[3].set_ylabel("SAT Participation Rate")
ax[3].set_title('Family Income vs SAT Participation Rate')

fig.tight_layout()
plt.show();

# %% [markdown]
# **Interpretation:**
# Median Family Income has positive correlation to ACT Composite Scores. Data seems to suggest however, that it has a negative correlation with ACT Participation Rate while a positive correlation with SAT Participation Rate.

# %%
#linear regression model fit for family income vs state total spending and spending per student

fig, ax = plt.subplots(2, figsize=(10, 10))

sns.regplot(ax = ax[0], x = df5['Family Income'], y = df5['Spending Total'])
ax[0].set_xlabel("Family Income")
ax[0].set_ylabel("Spending Total")
ax[0].set_title('Family Income vs Total Education Spending')


sns.regplot(ax = ax[1], x = df5['Family Income'], y = df5['Spending Per Student'])
ax[1].set_xlabel("Family Income")
ax[1].set_ylabel("Spending Per Student")
ax[1].set_title('Family Income vs Education Spending Per Student')

fig.tight_layout()
plt.show();

# %% [markdown]
# **Interpretation:**
# The Median Family Income does not have an impact on the total spending on education by states. However, as the Median Family Income increases, the spending per student by state increases; positively correlated.

# %%
#linear regression model fit for spending vs score and participation rate

fig, ax = plt.subplots(4, figsize=(10, 20))

sns.regplot(ax = ax[0], x = df5['Spending Per Student'], y = df5['ACT Composite'])
ax[0].set_xlabel("Spending Per Student")
ax[0].set_ylabel("ACT Composite")
ax[0].set_title('Education Spending Per Student vs ACT Composite Score')

sns.regplot(ax = ax[1], x = df5['Spending Per Student'], y = df5['SAT Total'])
ax[1].set_xlabel("Spending Per Student")
ax[1].set_ylabel("SAT Composite")
ax[1].set_title('Education Spending Per Student vs SAT Total Score')

sns.regplot(ax = ax[2], x = df5['Spending Per Student'], y = df5['ACT Participation Rate'])
ax[2].set_xlabel("Spending Per Student")
ax[2].set_ylabel("ACT Participation Rate")
ax[2].set_title('Education Spending Per Student vs ACT Participation Rate')

sns.regplot(ax = ax[3], x = df5['Spending Per Student'], y = df5['SAT Participation Rate'])
ax[3].set_xlabel("Spending Per Student")
ax[3].set_ylabel("SAT Participation Rate")
ax[3].set_title('Education Spending Per Student vs SAT Participation Rate')

fig.tight_layout()
plt.show();

# %% [markdown]
# **Interpretation:**
# Education Spending Per Student only seem to affect ACT Composite Score. There is an increasing trend, where ACT Composite Score increases when Education Spending Per Student. Education Spending Per Student does not seem to affect the SAT Total Score or ACT/SAT Participation Rate.

# %%
#new df for normalised data

final = pd.DataFrame([(df5[x]-df5[x].min())/
                             (df5[x].max()-df5[x].min()) for x in df5 if df5[x].dtypes != object]).T

# %%
#box plot for normalised parameters

plt.figure(figsize =(10,10))
sns.boxplot(data=final, 
            width=0.3,
           orient='h');
plt.title('Boxplot of normalised parameters in data collected for 2019',fontsize=20);

# %% [markdown]
# **Interpretation:**
# - Distribution of ACT Participation Rate is higher range compared to the SAT Participation Rate but the median is quite close
# - Distribution and median for both ACT and SAT Total/Composite Scores are very close
# - There are many some outliers in Total Education Spending, but it is positively skewed
# - Education Spending Per Student is positively skewed
# - Median Family Income shows an almost normal distribution

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ## Conclusion:
# ### Are there any correlation between SAT and ACT participation rates and scores as well as external factors?
# - Based on the data that we explored above, the correlation between SAT and ACT participation rates and scores were that they were negatively correlated. So it would not be effective to work towards increasing the participation rates.
# - Median Family Income has positive correlation to ACT Composite Scores. Data seems to suggest however, that it has a negative correlation with ACT Participation Rate while a positive correlation with SAT Participation Rate.
#
# ### Are there any score or participation rate bias for households with higher or lower median income?
# - Median Family Income has positive correlation to ACT Composite Scores. Data seems to suggest however, that it has a negative correlation with ACT Participation Rate while a positive correlation with SAT Participation Rate. This is rather strange because logically, higher median family inccome should give higher scores as families will be able to afford more tuition, classes, etc.
#
# ### Does education spending play a part in higher SAT or ACT scores?
# - Nevada, Mississippi, Alabama, Lousiana and Oklahoma not only have one of the highest participation rate for 2019 ACT and they scored one the lowest for 2019 ACT, they also have lower than National Average Per Student Spending
# - New York, North Dakota, Rhode Island, Massachusetts, Connecticut, New Hampshire were states with the highest ACT/SAT scores and their Per Student Education Spending was above the National Average Per Student Spending
# - This shows that education spending does play a part in SAT or ACT scores.
#
#
# ## Recommendation:
# It does not seem to be effective to simply try to increase participation rate as high participation rate does not neccessarily translate to higher scores. However, a suggestion would be using the absolute participate instead of the participation rate. Family income is also not a factor that can be easily altered without changing other Government policies, however, it can be seen that as Median Family Income increases, the Per Student Education Spending increases. This could be due to states being more affluent and therefore, the state has more tax income to spend on education. What we can focus on as Department of Education is try to get more funding for Per Student Education Spending, particularly in the states underperforming mentioned in EDA (Nevada, Mississippi, Alabama, Lousiana and Oklahoma).

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
